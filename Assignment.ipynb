# %% [markdown]
# <h2>PRN No: 12110033</h2> <h2>VIT Collage</h2>

# %% [markdown]
# <h1> Taabi Mobility Assignment </h1>

# %% [markdown]
# <h2>Step 1: Data Loading </h2>

# %% [markdown]
# <p> The given data is in excel formate. pandas with openpyxl can be use load the data into df, df is the  dataframe object that stores dataset and then df can process through out the Assignmnet. <p>

# %%
#impoting the require libraries
import pandas as pd
import openpyxl
import numpy as np
# Load the Excel file
file_path = '/dataset.xlsx'  # giving the file path 

df = pd.read_excel(file_path, engine='openpyxl') #loading the excel data into df

# Display the first few rows
print(df.head())
# Out:
#        uniqueid          ts        lat        lng  external_bat_voltage
# 0  it_220403501  1709340731  19.069340  78.355148                   NaN  \
# 1  it_220403501  1709340794  19.069347  78.355141                   NaN
# 2  it_220403501  1709340857  19.069414  78.355179                   NaN
# 3  it_220403501  1709340920  19.069258  78.355225                   NaN
# 4  it_220403501  1709340983  19.069094  78.355339                   NaN
#
#    internal_bat_voltage  engineload  tanklevel  throttle  coolant  ...
# 0                   NaN          28        NaN       NaN       33  ...  \
# 1                   NaN          22        NaN       NaN       41  ...
# 2                   NaN          25        NaN       NaN       48  ...
# 3                   NaN          35        NaN       NaN       52  ...
# 4                   NaN           0        NaN       NaN       57  ...
#
#    live_location  to_be_expired_at  status  event_id
# ...

# %% [markdown]
# <p> df.info() method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage. </p>

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18434 entries, 0 to 18433
# Columns: 141 entries, uniqueid to adblue_level
# dtypes: float64(122), int64(13), object(6)
# memory usage: 19.8+ MB
# None

# %% [markdown]
# <P> according to given data there are 18434 entries which means rows and 141 columns which can be called as variables, inthe given variables there 122 variable are float datatype, 13  int64 datatype and 6 objects  and  data uses memory of 19.8+  MB</P>

# %% [markdown]
# <p>
#
# describe() method is use to Descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.
# Analyzes both numeric and object series, as well as DataFrame column sets of mixed data types. The output will vary depending on what is provided. Refer to the notes below for more detail.
# </p>

# %%
df.describe()
# Out:
#                  ts           lat           lng  external_bat_voltage
# count  1.843400e+04  18434.000000  18434.000000                   0.0  \
# mean   1.711641e+09     18.724254     78.865351                   NaN
# std    1.275937e+06      0.816184      3.208032                   NaN
# min    1.709341e+09      0.000000      0.000000                   NaN
# 25%    1.710903e+09     18.701308     78.758909                   NaN
# 50%    1.711692e+09     18.853032     79.092408                   NaN
# 75%    1.712682e+09     18.921385     79.352821                   NaN
# max    1.713636e+09     19.069500     79.481804                   NaN
#
#        internal_bat_voltage    engineload  tanklevel  throttle       coolant
# count                   0.0  18434.000000        0.0       0.0  18434.000000  \
# mean                    NaN     38.141206        NaN       NaN     84.571336
# std                     NaN     29.889358        NaN       NaN      7.718346
# ...

# %% [markdown]
# <p>To  find DataType of each variable df.types can be use which dispalys datatype of each variable </p>

# %%
# Display the data types of each column
print(df.dtypes)
# Out:
# uniqueid                          object
# ts                                 int64
# lat                              float64
# lng                              float64
# external_bat_voltage             float64
#                                   ...
# boost_pressure                   float64
# intake_manifold_1_temperature    float64
# air_inlet_pressure               float64
# exhaust_gas_temperature          float64
# adblue_level                     float64
# Length: 141, dtype: object

# %% [markdown]
# df.shape retruns the pair of intigers which are no. rows  and no. of columns in the dataset there are 1834 rows and 141 columns as seen above info method

# %%
# Get the number of rows and columns
num_rows, num_cols = df.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_cols}")
# Out:
# Number of rows: 18434
# Number of columns: 141

# %% [markdown]
# isnull() returns a boolean same-sized object indicating if the values are NA. NA values, such as None or numpy.NaN, gets mapped to True values. Everything else gets mapped to False values. Characters such as empty strings '' or numpy.inf are not considered NA values (unless you set pandas.options.mode.use_inf_as_na = True). sum() method is used to sum up all the rows which as null values for each row and then it also find the percentage of null values in each row results can be displays below code

# %%
# Check for missing values in each column
missing_values = df.isnull().sum()
print("Missing values in each column:")
print(missing_values)

# Calculate the percentage of missing values
missing_percentage = (df.isnull().sum() / len(df)) * 100
print("Percentage of missing values in each column:")
print(missing_percentage)
# Out:
# Missing values in each column:
# uniqueid                             0
# ts                                   0
# lat                                  0
# lng                                  0
# external_bat_voltage             18434
#                                  ...
# boost_pressure                   18434
# intake_manifold_1_temperature    18434
# air_inlet_pressure               18434
# exhaust_gas_temperature          18434
# adblue_level                      3664
# Length: 141, dtype: int64
# Percentage of missing values in each column:
# uniqueid                           0.000000
# ts                                 0.000000
# lat                                0.000000
# lng                                0.000000
# external_bat_voltage             100.000000
#                                     ...
# boost_pressure                   100.000000
# intake_manifold_1_temperature    100.000000
# air_inlet_pressure               100.000000
# ...

# %%
# Find unique values for each column
unique_values = df.apply(lambda x: x.unique())

# Display unique values
print("Unique values per column:\n", unique_values)
# Out:
# Unique values per column:
#  uniqueid                                                            [it_220403501]
# ts                               [1709340731, 1709340794, 1709340857, 170934092...
# lat                              [19.06934, 19.069347, 19.069414, 19.069258, 19...
# lng                              [78.355148, 78.355141, 78.355179, 78.355225, 7...
# external_bat_voltage                                                         [nan]
#                                                        ...
# boost_pressure                                                               [nan]
# intake_manifold_1_temperature                                                [nan]
# air_inlet_pressure                                                           [nan]
# exhaust_gas_temperature                                                      [nan]
# adblue_level                     [nan, 52.400000000000006, 51.6, 50.40000000000...
# Length: 141, dtype: object

# %%
# Check for duplicate rows
duplicates = df.duplicated().sum()

# Display number of duplicate rows
print("Number of duplicate rows:", duplicates)
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# <h2> Step 2: Data Cleaning and Data Preprocessing </h2>

# %% [markdown]
# <p> In previous step we see find there are columns are completely null so lets find the no of columns are totally null using isna().all() find the columns are totally null are not are .sum() method sum up the all columns so according to out put there are 108 columns are there which completely null. those columns cannot use for analysis. So those columns need to remove</p>

# %%
# Count the number of columns that are completely null
null_columns_count = df.isna().all().sum()

print(null_columns_count)
# Out:
# 108

# %% [markdown]
# the .dropna() method is use to remove the columns or row which have null values we can set options according to aur need like, axis which can be set 1 for columns and 0 for rows. and the other option is how which can set any which need atleast one cell to be null to remove and all which need every cell to null for remove column or row . In below code axis set to 1 and how set to be all which drops columns which as all nill values after removing columns generates new dataframe which as 33 columns that stored in df_cleaned dataframe

# %%
# Drop columns that are completely null
df_cleaned = df.dropna(axis=1, how='all')

print(df_cleaned)
# Out:
#            uniqueid          ts        lat        lng  engineload  coolant
# 0      it_220403501  1709340731  19.069340  78.355148          28       33  \
# 1      it_220403501  1709340794  19.069347  78.355141          22       41
# 2      it_220403501  1709340857  19.069414  78.355179          25       48
# 3      it_220403501  1709340920  19.069258  78.355225          35       52
# 4      it_220403501  1709340983  19.069094  78.355339           0       57
# ...             ...         ...        ...        ...         ...      ...
# 18429  it_220403501  1713635865  18.869371  79.020393          50       89
# 18430  it_220403501  1713635929  18.867130  79.018272           0       92
# 18431  it_220403501  1713635993  18.862076  79.013924          10       87
# 18432  it_220403501  1713636056  18.859493  79.011673          52       87
# 18433  it_220403501  1713636120  18.858324  79.009033          72       90
#
#        engineoiltemp  vehiclespeed       rpm  obddistance  ...
# ...

# %% [markdown]
# In the given dataframe some  column as only one unique valuel, so it can be drop from the data because doesn't have any use

# %%
# Identify columns with only one unique value
unique_counts = df_cleaned.nunique()

# Display columns with only one unique value
print("Columns with only one unique value:\n", unique_counts[unique_counts == 1].index)
# Out:
# Columns with only one unique value:
#  Index(['uniqueid', 'engineoiltemp', 'selected_gear', 'vibration_status',
#        'engine_throttle_valve2_pos', 'enginefueltemp',
#        'accelerator_pedal_pos_2'],
#       dtype='object')

# %%
# Drop columns with only one unique value
df_cleaned = df_cleaned.drop(columns=unique_counts[unique_counts == 1].index)

# Display the cleaned DataFrame
print("\nDataFrame after dropping columns with only one unique value:\n", df_cleaned)
# Out:
# DataFrame after dropping columns with only one unique value:
#                 ts        lat        lng  engineload  coolant  vehiclespeed
# 0      1709340731  19.069340  78.355148          28       33       0.00000  \
# 1      1709340794  19.069347  78.355141          22       41       0.00000
# 2      1709340857  19.069414  78.355179          25       48       1.40625
# 3      1709340920  19.069258  78.355225          35       52       2.81250
# 4      1709340983  19.069094  78.355339           0       57       4.53125
# ...           ...        ...        ...         ...      ...           ...
# 18429  1713635865  18.869371  79.020393          50       89      14.28125
# 18430  1713635929  18.867130  79.018272           0       92      38.28125
# 18431  1713635993  18.862076  79.013924          10       87      32.34375
# 18432  1713636056  18.859493  79.011673          52       87      17.71875
# 18433  1713636120  18.858324  79.009033          72       90      16.21875
#
# ...

# %%
df_cleaned.info() # cleaned data summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18434 entries, 0 to 18433
# Data columns (total 26 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ts                                    18434 non-null  int64
#  1   lat                                   18434 non-null  float64
#  2   lng                                   18434 non-null  float64
#  3   engineload                            18434 non-null  int64
#  4   coolant                               18434 non-null  int64
#  5   vehiclespeed                          18434 non-null  float64
#  6   rpm                                   18434 non-null  float64
#  7   obddistance                           18434 non-null  int64
#  8   runtime                               18420 non-null  float64
#  9   engine_torque_percent                 18434 non-null  int64
#  10  current_gear                          18434 non-null  int64
# ...

# %%
df_cleaned.describe()  # cleaned data summary
# Out:
#                  ts           lat           lng    engineload       coolant
# count  1.843400e+04  18434.000000  18434.000000  18434.000000  18434.000000  \
# mean   1.711641e+09     18.724254     78.865351     38.141206     84.571336
# std    1.275937e+06      0.816184      3.208032     29.889358      7.718346
# min    1.709341e+09      0.000000      0.000000      0.000000     30.000000
# 25%    1.710903e+09     18.701308     78.758909     10.000000     83.000000
# 50%    1.711692e+09     18.853032     79.092408     31.000000     85.000000
# 75%    1.712682e+09     18.921385     79.352821     64.000000     89.000000
# max    1.713636e+09     19.069500     79.481804    100.000000     98.000000
#
#        vehiclespeed           rpm   obddistance       runtime
# count  18434.000000  18434.000000  1.843400e+04  18420.000000  \
# mean      33.361762    937.044090  6.650076e+07   2132.411732
# std       17.929579    327.003819  3.256334e+06     92.454295
# ...

# %%
print(df_cleaned.head())
# Out:
#            ts        lat        lng  engineload  coolant  vehiclespeed
# 0  1709340731  19.069340  78.355148          28       33       0.00000  \
# 1  1709340794  19.069347  78.355141          22       41       0.00000
# 2  1709340857  19.069414  78.355179          25       48       1.40625
# 3  1709340920  19.069258  78.355225          35       52       2.81250
# 4  1709340983  19.069094  78.355339           0       57       4.53125
#
#         rpm  obddistance  runtime  engine_torque_percent  ...
# 0   749.000     60780800  1970.85                     21  ...  \
# 1  1208.375     60780800  1970.85                     18  ...
# 2   752.625     60780800  1970.85                     18  ...
# 3   996.375     60780820  1970.90                     27  ...
# 4  1065.750     60780840  1970.90                      1  ...
#
#    accelerator_pedal_pos   pluscode
# 0                    0.0  7JFW3994+  \
# 1                   23.6  7JFW3994+
# 2                    0.0  7JFW3994+
# ...

# %%
# Check for missing values in each column
missing_values = df_cleaned.isnull().sum()
print("Missing values in each column:")
print(missing_values)

# Calculate the percentage of missing values
missing_percentage = (df_cleaned.isnull().sum() / len(df)) * 100
print("Percentage of missing values in each column:")
print(missing_percentage)
# Out:
# Missing values in each column:
# ts                                         0
# lat                                        0
# lng                                        0
# engineload                                 0
# coolant                                    0
# vehiclespeed                               0
# rpm                                        0
# obddistance                                0
# runtime                                   14
# engine_torque_percent                      0
# current_gear                               0
# fuel_consumption                           0
# fuel_level                                 2
# fl_level                                   0
# fuel_rate                                  0
# fuel_economy                               0
# accelerator_pedal_pos                      0
# pluscode                                   0
# can_raw_data                               0
# engine_throttle_valve1_pos                 0
# ...

# %% [markdown]
# Since there are three columns with null values two of them are having low percent of null values which can handle by replace the null values with mean, median or some other imputations.

# %% [markdown]
# The three columns runtime and fuel_level has very low percentage of missing values so that can be handle with mean or median imputations in this case median imputation best option because it Robustness to Outliers and Central Tendency one imporatnt note is that this two column doesn't contain any zeros this only contains NA values so direct imputaion can be done.

# %%
df_cleaned['runtime'].fillna(df_cleaned['runtime'].median(), inplace=True) #replaceing null values with median for runtime column

df_cleaned['fuel_level'].fillna(df_cleaned['fuel_level'].median(), inplace=True) #replaceing null values with median for fuel_level column
 df_cleaned['adblue_level'].fillna(df_cleaned['adblue_level'].median(), inplace=True) #replaceing null values with median for fuel_level column

# %%
# Check for missing values in each column
missing_values = df_cleaned.isnull().sum()
print("Missing values in each column:")
print(missing_values)

# Calculate the percentage of missing values
missing_percentage = (df_cleaned.isnull().sum() / len(df)) * 100
print("Percentage of missing values in each column:")
print(missing_percentage)
# Out:
# Missing values in each column:
# ts                                         0
# lat                                        0
# lng                                        0
# engineload                                 0
# coolant                                    0
# vehiclespeed                               0
# rpm                                        0
# obddistance                                0
# runtime                                    0
# engine_torque_percent                      0
# current_gear                               0
# fuel_consumption                           0
# fuel_level                                 0
# fl_level                                   0
# fuel_rate                                  0
# fuel_economy                               0
# accelerator_pedal_pos                      0
# pluscode                                   0
# can_raw_data                               0
# engine_throttle_valve1_pos                 0
# ...

# %% [markdown]
# In the data set there are three columns brake_switch_status , clutch_switch_status ,parking_switch_status having two categories Released and Pressed for future steps the columns can be convert into integers which can map Released and Pressed ehich are 0, 1 also changing data type of the columns into int

# %%
import pandas as pd


df_cleaned['brake_switch_status'] = df_cleaned['brake_switch_status'].map({'Released': 1, 'Pressed': 0})

# Optionally, ensure the data type is integer
df_cleaned['brake_switch_status'] = df_cleaned['brake_switch_status'].astype(int)

# %%
df_cleaned['clutch_switch_status'] = df_cleaned['clutch_switch_status'].map({'Released': 1, 'Pressed': 0})
df_cleaned['parking_switch_status'] = df_cleaned['parking_switch_status'].map({'Released': 1, 'Pressed': 0})

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18434 entries, 0 to 18433
# Data columns (total 26 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ts                                    18434 non-null  int64
#  1   lat                                   18434 non-null  float64
#  2   lng                                   18434 non-null  float64
#  3   engineload                            18434 non-null  int64
#  4   coolant                               18434 non-null  int64
#  5   vehiclespeed                          18434 non-null  float64
#  6   rpm                                   18434 non-null  float64
#  7   obddistance                           18434 non-null  int64
#  8   runtime                               18434 non-null  float64
#  9   engine_torque_percent                 18434 non-null  int64
#  10  current_gear                          18434 non-null  int64
# ...

# %%
df_cleaned.head()
# Out:
#            ts        lat        lng  engineload  coolant  vehiclespeed
# 0  1709340731  19.069340  78.355148          28       33       0.00000  \
# 1  1709340794  19.069347  78.355141          22       41       0.00000
# 2  1709340857  19.069414  78.355179          25       48       1.40625
# 3  1709340920  19.069258  78.355225          35       52       2.81250
# 4  1709340983  19.069094  78.355339           0       57       4.53125
#
#         rpm  obddistance  runtime  engine_torque_percent  ...
# 0   749.000     60780800  1970.85                     21  ...  \
# 1  1208.375     60780800  1970.85                     18  ...
# 2   752.625     60780800  1970.85                     18  ...
# 3   996.375     60780820  1970.90                     27  ...
# 4  1065.750     60780840  1970.90                      1  ...
#
#    accelerator_pedal_pos   pluscode
# 0                    0.0  7JFW3994+  \
# 1                   23.6  7JFW3994+
# 2                    0.0  7JFW3994+
# ...

# %% [markdown]
# Now to find outliers visualisation can be use. So for the skewness histogram plot can be and for that seaborn library can be use

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df_cleaned['lng'], kde=True)

plt.subplot(1,2,2)

sns.histplot(df_cleaned['lat'], kde=True)

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df_cleaned['engineload'], kde=True)

plt.subplot(1,2,2)

sns.histplot(df_cleaned['coolant'], kde=True)

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df_cleaned['vehiclespeed'], kde=True)

plt.subplot(1,2,2)

sns.histplot(df_cleaned['rpm'], kde=True)

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df_cleaned['obddistance'], kde=True)

plt.subplot(1,2,2)

sns.histplot(df_cleaned['engine_torque_percent'], kde=True)

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df_cleaned['runtime'], kde=True)

plt.subplot(1,2,2)

sns.histplot(df_cleaned['current_gear'], kde=True)

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df_cleaned['fl_level'], kde=True)

plt.subplot(1,2,2)

sns.histplot(df_cleaned['fuel_level'], kde=True)

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df_cleaned['fuel_consumption'], kde=True)

plt.subplot(1,2,2)

sns.histplot(df_cleaned['fuel_rate'], kde=True)

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df_cleaned['accelerator_pedal_pos'], kde=True)

plt.subplot(1,2,2)

sns.histplot(df_cleaned['engine_throttle_valve1_pos'], kde=True)

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df_cleaned['engine_torque_mode'], kde=True)

plt.subplot(1,2,2)

sns.histplot(df_cleaned['drivers_demand_engine_torque_percent'], kde=True)

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df_cleaned['adblue_level'], kde=True)
# Out:
# <Axes: xlabel='adblue_level', ylabel='Count'>

# %% [markdown]
# there are alternate method to find sckewness of the data which is .skew() method lets see

# %%
print (df_cleaned['rpm'].skew()) # finding skewness for rpm column

df_cleaned['rpm'].describe()
# Out:
# -1.016179388653725
# count    18434.000000
# mean       937.044090
# std        327.003819
# min          0.000000
# 25%        757.250000
# 50%        950.812500
# 75%       1157.500000
# max       2011.250000
# Name: rpm, dtype: float64

# %%
sns.boxplot(df['rpm']) # ploting box plot for rpm column
# Out:
# <Axes: >

# %% [markdown]
# from above box there are outliers present in thr rpm columns so to remove there are two method remove the outliers or capping the outlier methodlets perform both fo both method IQR use which use to lower limit and upper limit

# %%
percentile25 = df['rpm'].quantile(0.25) #1st quartile of the column 
percentile75 = df['rpm'].quantile(0.75) #3rd quartile of the column
percentile75
iqr = percentile75 - percentile25 #calculating IQR

# %%
upper_limit = percentile75 + 1.5 * iqr #finding upper limit and lower limit which consist 3 standard deviation which will over 90 percentile
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
lower_limit
# Out:
# 1757.875
# 156.875

# %% [markdown]
# finding the outliers uisng lower and upper limit

# %%
df_cleaned[df_cleaned['rpm'] > upper_limit]
# Out:
#                ts        lat        lng  engineload  coolant  vehiclespeed
# 2736   1709865890  17.697968  78.604820          48       90     40.875000  \
# 4252   1710251621  18.151194  78.952171          70       92     37.281250
# 5588   1711052072  18.792553  78.910774          42       78     19.750000
# 6347   1711151945  18.468109  79.138115          17       89     14.609375
# 8243   1711505052  18.901377  79.158531          68       87     37.328125
# 8918   1711646166  18.927629  79.044380          84       94     20.484375
# 8923   1711646488  18.900126  79.029922           0       92     45.515625
# 9051   1711654708  18.830736  78.459267          26       86     38.125000
# 9391   1711711206  19.032177  79.440514          37       91     39.890625
# 10076  1711921729  19.034637  79.356216          23       47      0.000000
# 10895  1712093565  18.909298  79.179604           0       88     71.515625
# ...

# %%
new_df = df_cleaned[(df_cleaned['rpm'] < upper_limit) & (df_cleaned['rpm'] > lower_limit)]

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.histplot(df_cleaned['rpm'], kde=True)

plt.subplot(2,2,2)
sns.boxplot(df_cleaned['rpm'])

plt.subplot(2,2,3)
sns.histplot(new_df['rpm'] ,kde=True) 

plt.subplot(2,2,4)
sns.boxplot(new_df['rpm'])

plt.show()

# %% [markdown]
# now lets see capping proccess using IQR for that using fuel_rate columns

# %%
print (df_cleaned['current_gear'].skew()) # finding skewness for rpm column

df_cleaned['current_gear'].describe()
# Out:
# 4.8070849909699085
# count    18434.000000
# mean        13.550071
# std         20.066883
# min          0.000000
# 25%          0.000000
# 50%         15.000000
# 75%         17.000000
# max        129.000000
# Name: current_gear, dtype: float64

# %%
sns.boxplot(df['current_gear']) # ploting box plot for rpm column
# Out:
# <Axes: >

# %%
upper_limit = percentile75 + 1.5 * iqr #finding upper limit and lower limit which consist 3 standard deviation which will over 90 percentile
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
lower_limit
# Out:
# 83.990234375
# -14.619140625

# %%
percentile25 = df['current_gear'].quantile(0.25) #1st quartile of the column 
percentile75 = df['current_gear'].quantile(0.75) #3rd quartile of the column
percentile75
iqr = percentile75 - percentile25 #calculating IQR

# %%
upper_limit = percentile75 + 1.5 * iqr #finding upper limit and lower limit which consist 3 standard deviation which will over 90 percentile
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
lower_limit
# Out:
# 42.5
# -25.5

# %%
df_cleaned[df_cleaned['vehiclespeed'] > upper_limit]
# Out:
#                ts        lat        lng  engineload  coolant  vehiclespeed
# 46     1709353149  19.043056  78.353966          35       84     44.015625  \
# 47     1709353214  19.037655  78.358025          51       83     42.531250
# 48     1709353279  19.031239  78.361214          21       84     48.515625
# 51     1709353472  19.014313  78.367203          38       83     44.750000
# 52     1709353537  19.008863  78.372993          10       81     44.593750
# ...           ...        ...        ...         ...      ...           ...
# 18387  1713633177  18.914301  79.126884          10       89     51.375000
# 18388  1713633242  18.919693  79.121864          69       85     46.828125
# 18390  1713633371  18.929543  79.110672          74       91     50.359375
# 18391  1713633436  18.935272  79.104210          10       88     57.234375
# 18396  1713633758  18.942858  79.079041          36       92     44.015625
#
#             rpm  obddistance  runtime  engine_torque_percent  ...
# ...

# %%
new_df_cap = df_cleaned.copy()

new_df_cap['current_gear'] = np.where(
    new_df_cap['current_gear'] > upper_limit,
    upper_limit,
    np.where(
        new_df_cap['current_gear'] < lower_limit,
        lower_limit,
        new_df_cap['current_gear']
    )
)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.histplot(df_cleaned['current_gear'], kde=True)

plt.subplot(2,2,2)
sns.boxplot(df_cleaned['current_gear'])

plt.subplot(2,2,3)
sns.histplot(new_df_cap['current_gear'], kde=True)

plt.subplot(2,2,4)
sns.boxplot(new_df_cap['current_gear'])

plt.show()

# %% [markdown]
# after capping it can observe that there is increase point near 45 because during the capping process outliers decrease into lower and upper respectily that why there is increse in obersevation at 45 gear

# %% [markdown]
# <h1> Step 3 : Exploratory data analysis </h1>

# %% [markdown]
# Now after cleaning the data now can lets see some compartive analysis between two features let select rpm and current gear column beacuse they are can exist an relation.

# %%
import matplotlib.pyplot as plt

# Create a scatter plot
plt.scatter(df_cleaned['engineload'], df_cleaned['rpm'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('engineload')
plt.ylabel('RPM')
plt.title('Scatter Plot of RPM vs engineload')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df_cleaned['fl_level'], df_cleaned['fuel_level'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('fl_level')
plt.ylabel('fuel_level')
plt.title('Scatter Plot of fuel_level vs fl_level')

# Show the plot
plt.show()

# %% [markdown]
# in the above fuel_level vs fl_level graph we can see they are showing same data point therefore both column are adressing same attribute which is fuel level

# %%
# Create a scatter plot
plt.scatter(df_cleaned['rpm'], df_cleaned['vehiclespeed'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('rpm')
plt.ylabel('vehiclespeed')
plt.title('Scatter Plot of adblue_level vs fl_level')

# Show the plot
plt.show()

# %% [markdown]
# there is direct relation between rpm and vehicle speed but there is other depend variable which determine becuase at middle 750 there is huge spike which shows some other attribute affecting vehicle speed could it be torque which also related to speed and rpm both lets see

# %%
# Create a scatter plot
plt.scatter(df_cleaned['drivers_demand_engine_torque_percent'], df_cleaned['vehiclespeed'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('vehiclespeed')
plt.ylabel('drivers_demand_engine_torque_percent')


# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df_cleaned['vehiclespeed'], df_cleaned['fuel_consumption'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('adblue_level')
plt.ylabel('vehiclespeed')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df_cleaned['runtime'], df_cleaned['fuel_consumption'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('runtime')
plt.ylabel('fuel_consumption')

# Show the plot
plt.show()

# %% [markdown]
# in above scatter plot it can be evidently see that runtime and fuel consuption are in linear relationship which make sence because runtime can effect fuel consuption

# %%
# Create a scatter plot
plt.scatter(df_cleaned['runtime'], df_cleaned['obddistance'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('runtime')
plt.ylabel('obddistance')

# Show the plot
plt.show()

# %% [markdown]
# so as evidently we can see that obdistance and run time in linear relation because its simple obdistance increases then runtime is going to increase

# %%
# Create a scatter plot
plt.scatter(df_cleaned['runtime'], df_cleaned['coolant'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('runtime')
plt.ylabel('coolant')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df_cleaned['runtime'], df_cleaned['engineload'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('runtime')
plt.ylabel('engineload')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df_cleaned['runtime'], df_cleaned['engineload'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('runtime')
plt.ylabel('obddistance')

# Show the plot
plt.show()

# %% [markdown]
# <h2>Conclusion of analysis</h2>
# After analysis it's seems that there is relation between obdistance and runtime and fuel consumption So lets discuss in real life example a vehicle runtime can increses when ever car in running if car is running then its cover some distance which is nothing but obdistance is we can say that runtime and obdistance is independent varible on the other hand we can find that incresee in runtime is affect engine beacuse that fuel consumption in also increasing so according to runtime and oddistance we can say fuel consumption vary. So after analysis it evidently see that runtime increses then fuel consumption increses in other words older vehicle can consume more fuel than newer vehicle

# %% [markdown]
# <h1>Step 4 : Feature Engineering </h1>

# %% [markdown]
# <h3>In above analysis we find that obdistance and runtime are in linear relation so that we can also calculate average speed a vehicle is travel so let add feature of average velocity of vehicle in dataframe </h3>

# %%
# Calculate average velocity and create a new column
df_cleaned['average_velocity'] = df_cleaned['obddistance']/1000 / (df_cleaned['runtime']) # distance is in meter so it is appropriate to convert into km

# Display the first few rows to check the result
print(df_cleaned[['runtime', 'obddistance', 'average_velocity']].head())
# Out:
#    runtime  obddistance  average_velocity
# 0  1970.85     60780800         30.839891
# 1  1970.85     60780800         30.839891
# 2  1970.85     60780800         30.839891
# 3  1970.90     60780820         30.839119
# 4  1970.90     60780840         30.839129

# %% [markdown]
# <h5>New feature average velocity aded to dataframe so lets it has any relation between other attribute of dataframe</h5>

# %%
# Create a scatter plot
plt.scatter(df_cleaned['fuel_consumption'], df_cleaned['average_velocity'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('fuel_consumption')
plt.ylabel('average_velocity')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df_cleaned['fuel_level'], df_cleaned['average_velocity'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('fuel_level')
plt.ylabel('average_velocity')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df_cleaned['rpm'], df_cleaned['average_velocity'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('rpm')
plt.ylabel('average_velocity')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df_cleaned['engine_torque_percent'], df_cleaned['average_velocity'], color='blue', alpha=0.6)

# Add titles and labels
plt.xlabel('engine_torque_percent')
plt.ylabel('average_velocity')

# Show the plot
plt.show()

# %% [markdown]
# <h1>Results</h1>
# <h5>
#     After analysing the given data if run and obd distance of vehicle increases the engine get affected over the time and because of that the fuel consumption is also increses. So the much older vehicle can consume fuel which can be increse the cost of travelling so it is best practice to do full service of vehicle and it engine at some intervel of time if vehicle is very old then it is better change the vehicle.
# </h5>

# %% [markdown]
# <h1>Author</h1>
# <h4> Srinivas Chenna  (Student at VIT, Pune)</h4>
